# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/maindatasetfinal2/train_task2.csv
# /kaggle/input/datasettask2test/task2_test.csv

# %%
import numpy as np
import regex as re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
import math
import os
import keras
import gzip
import csv

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras.backend as K
import tokenizers
from transformers import XLNetTokenizer, TFXLNetModel

from collections import Counter

import warnings
warnings.filterwarnings("ignore")

# %%
def preprocess(text):
    text=text.lower()
    text=re.sub(r'rt\s*@[^:]*:\s', ' ', text)
    text=re.sub(r'[^A-Za-z0-9]+', ' ', text)
    text=re.sub(r' t .*$', '', text)
    text=re.sub(r'\b[a-zA-Z]\b', '', text)
    text=re.sub(r'/^\s+|\s+$|\s+(?=\s)/g', '', text);
    text = re.sub(r's+[a-zA-Z]s+', '', text)
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)
    text=re.sub(r'https?','',text)
    text=re.sub(r'#[A-Za-z0-9_]+','',text)
    text=re.sub(r'\.\.\.',' ',text)
    text=text.replace('…',' ')
    text=text.replace('..',' ')
    text=re.sub(r'@\w*',r'',text)
    text=re.sub(r'\s{2,}',r' ',text)
    text=re.sub(r'$[\s]+','',text)
    text=text.replace('&amp','')
    text=text.replace('&gt','')
    text=text.replace('&lt','')
    text=re.sub(r'([\w\d]+)([^\w\d ]+)', r'\1 \2',text)
    text=re.sub(r'([^\w\d ]+)([\w\d]+)', r'\1 \2',text)

    return text

# %%
train = pd.read_csv('../input/maindatasetfinal2/train_task2.csv')
train
# Out:
#                                               tweet_text text_human_class  \
# 0      no an undocumented immigrant did not start the...  non_informative
# 1      the massage therapi reaching out to those caug...     humanitarian
# 2       morning meeting we continue to tackle the dam...        structure
# 3      still waiting for my power to come back after ...  non_informative
# 4      floridians with solarpanels were able to get e...  non_informative
# ...                                                  ...              ...
# 27522  last tripadvisor review restaurant in amatrice...        structure
# 27523   drone shows damage around amatrice as rescue ...        structure
# 27524   convent among collapsed buildings in amatrice...        structure
# 27525   the sun ri over collapsed buildings following...        structure
# 27526  satellite pics show ground fallen 20 cms at ac...        structure
#
#        type
# 0         1
# 1         0
# 2         2
# 3         1
# 4         1
# ...     ...
# 27522     2
# 27523     2
# 27524     2
# 27525     2
# 27526     2
#
# [27527 rows x 3 columns]

# %%
test = pd.read_csv('../input/datasettask2test/task2_test.csv', index_col = 0)
del(test["tweet_id"])
del(test["image_id"])
del(test["image_path"])
del(test["text_info_conf"])
del(test["image_info"])
del(test["image_info_conf"])
del(test["text_human"])
del(test["text_human_conf"])
del(test["image_human"])
del(test["image_human_conf"])
del(test["image_damage"])
del(test["image_damage_conf"])
del(test["image_url"])
del(test["image_human_class"])
del(test["Unnamed: 0.1"])
del(test["text_info"])

test["tweet_text"]=test["tweet_text"].apply(lambda x: preprocess(x))
test["type"] = test["text_human_class"].apply(lambda x: 0 if x == "humanitarian"  else 1 if x == "non_informative" else 2)


test
# Out:
#                                               tweet_text text_human_class  \
# 11755  selling popcorn at lunch to benefit victims of...     humanitarian
# 1157   not only california northern spain amp portuga...  non_informative
# 16557  5pm tuesday tropical update maria still catego...  non_informative
# 7679   3 scenes of landsat ingested to hdds for event...  non_informative
# 196     realomarnavarro schnauzermom777 can you stop ...  non_informative
# ...                                                  ...              ...
# 2888                my town in pr after hurricane maria   non_informative
# 8619    stiletto in texas it more than shoe it an att...  non_informative
# 16509  help our members affected by harvey and irma d...     humanitarian
# 1418   california wine country wildfires near contain...  non_informative
# 91     playing with my new friend chai she california...  non_informative
#
#        type
# 11755     0
# 1157      1
# 16557     1
# 7679      1
# 196       1
# ...     ...
# 2888      1
# 8619      1
# 16509     0
# 1418      1
# 91        1
#
# [3617 rows x 3 columns]

# %%
train["text_human_class"].value_counts()
# Out:
# humanitarian       9549
# non_informative    9305
# structure          8673
# Name: text_human_class, dtype: int64

# %%
xlnet_model = 'xlnet-base-cased'
xlnet_tokenizer = XLNetTokenizer.from_pretrained(xlnet_model)
# Out:
# Downloading:   0%|          | 0.00/779k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/760 [00:00<?, ?B/s]

# %%
tokenized_train = train["tweet_text"].apply((lambda x: xlnet_tokenizer.encode(x, add_special_tokens=True, max_length=60)))
tokenized_test = test["tweet_text"].apply((lambda x: xlnet_tokenizer.encode(x, add_special_tokens=True, max_length=60)))
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
max_len = 0

for i in tokenized_train.values:
    if len(i) > max_len:
        max_len = len(i)

max_len
# Out:
# 60

# %%
input_ids_train= np.array([i + [0]*(max_len-len(i)) for i in tokenized_train.values])
attention_mask_train= np.where(input_ids_train!= 0, 1, 0)

input_ids_test= np.array([i + [0]*(max_len-len(i)) for i in tokenized_test.values])
attention_mask_test=np.where(input_ids_test!= 0, 1, 0)

# %%
arr_train = train["type"].values
arr_test = test["type"].values

num_samples_train = len(train)
num_samples_test = len(test)

labels_train = np.zeros((num_samples_train, arr_train.max()+1))
labels_test = np.zeros((num_samples_test, arr_test.max()+1))

labels_train[np.arange(num_samples_train), arr_train] = 1
labels_test[np.arange(num_samples_test), arr_test] = 1

# %%
dataset_train = tf.data.Dataset.from_tensor_slices((input_ids_train,attention_mask_train,labels_train))
dataset_test = tf.data.Dataset.from_tensor_slices((input_ids_test,attention_mask_test,labels_test))

def map_func(input_ids, masks, labels):
    return {'input_ids' : input_ids, 'attention_mask' : masks}, labels

dataset_train = dataset_train.map(map_func)
dataset_test = dataset_test.map(map_func)
# Out:
# 2022-05-16 21:40:03.121428: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-16 21:40:03.122765: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-16 21:40:03.123547: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-16 21:40:03.125870: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-16 21:40:03.126172: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-16 21:40:03.126964: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-16 21:40:03.127712: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-16 21:40:07.788318: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-16 21:40:07.789238: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-16 21:40:07.789980: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-16 21:40:07.791365: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14969 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
dataset_train = dataset_train.shuffle(4800)

dataset_train = dataset_train.batch(64)
dataset_test = dataset_test.batch(8)

# %%
def create_model_xlnet(xlnet_model):
    
    input_ids = tf.keras.layers.Input(shape=(max_len,), name = "input_ids", dtype = 'int32')
    mask = tf.keras.layers.Input(shape=(max_len,), name = "attention_mask", dtype = 'int32')

    
    xlnet = TFXLNetModel.from_pretrained(xlnet_model, output_hidden_states = True)
    last_layer = xlnet(input_ids, attention_mask=mask)[0]
    
    #conc_layer1 = hidden_layers[-4]
    #conc_layer2 = hidden_layers[-3]
    #conc_layer3 = hidden_layers[-2]
    #conc_layer4 = hidden_layers[-1]

    #conc = tf.keras.layers.Concatenate()([conc_layer1, conc_layer2, conc_layer3, conc_layer4])

    gru = tf.keras.layers.GRU(128, return_sequences=True)(last_layer)
    gru = tf.keras.layers.Dropout(0.2)(gru)
    gru = tf.keras.layers.GRU(64)(gru)
    gru = tf.keras.layers.Dropout(0.2)(gru)
    gru = tf.keras.layers.Dense(32)(gru)

    outputs = tf.keras.layers.Dense(3, activation='softmax', name='outputs')(gru)
    
    model = tf.keras.Model(inputs = [input_ids, mask], outputs = [outputs])

    return model

# %%
xlnet = create_model_xlnet(xlnet_model)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-5, decay = 0.01)
loss = tf.keras.losses.CategoricalCrossentropy()
metrics = METRICS = [
        tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
        tf.keras.metrics.Precision(name="precison"),
        tf.keras.metrics.Recall(name="recall")
    ]

es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
mc = keras.callbacks.ModelCheckpoint('/kaggle/working/XLNet_TASK2_best_model.h5', monitor='val_loss', mode='min', save_best_only=True)

xlnet.compile(optimizer=optimizer, loss = loss, metrics = metrics)

# %%
history = xlnet.fit(
    dataset_train,
    validation_data = dataset_test,
    epochs = 100,
    callbacks=[es,mc]
)
# Out:
# Epoch 1/100
# 2022-05-16 21:40:51.703299: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-05-16 21:40:56.247448: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 431/431 [==============================] - 267s 583ms/step - loss: 0.5297 - accuracy: 0.8030 - precison: 0.8222 - recall: 0.7750 - val_loss: 1.5551 - val_accuracy: 0.4495 - val_precison: 0.4507 - val_recall: 0.4255
# Epoch 2/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.3786 - accuracy: 0.8673 - precison: 0.8770 - recall: 0.8547 - val_loss: 1.1785 - val_accuracy: 0.5952 - val_precison: 0.6009 - val_recall: 0.5787
# Epoch 3/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.3436 - accuracy: 0.8778 - precison: 0.8859 - recall: 0.8686 - val_loss: 1.1954 - val_accuracy: 0.5928 - val_precison: 0.5998 - val_recall: 0.5784
# Epoch 4/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.3351 - accuracy: 0.8802 - precison: 0.8876 - recall: 0.8716 - val_loss: 1.0743 - val_accuracy: 0.6273 - val_precison: 0.6383 - val_recall: 0.6138
# Epoch 5/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.3299 - accuracy: 0.8831 - precison: 0.8903 - recall: 0.8745 - val_loss: 1.0146 - val_accuracy: 0.6450 - val_precison: 0.6534 - val_recall: 0.6276
# Epoch 6/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.3247 - accuracy: 0.8822 - precison: 0.8899 - recall: 0.8740 - val_loss: 0.9386 - val_accuracy: 0.6743 - val_precison: 0.6816 - val_recall: 0.6575
# Epoch 7/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.3200 - accuracy: 0.8851 - precison: 0.8921 - recall: 0.8769 - val_loss: 0.9322 - val_accuracy: 0.6743 - val_precison: 0.6826 - val_recall: 0.6569
# Epoch 8/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.3248 - accuracy: 0.8830 - precison: 0.8906 - recall: 0.8753 - val_loss: 0.8610 - val_accuracy: 0.6951 - val_precison: 0.7039 - val_recall: 0.6801
# Epoch 9/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.3175 - accuracy: 0.8846 - precison: 0.8920 - recall: 0.8765 - val_loss: 0.8363 - val_accuracy: 0.7072 - val_precison: 0.7151 - val_recall: 0.6931
# Epoch 10/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.3201 - accuracy: 0.8843 - precison: 0.8919 - recall: 0.8767 - val_loss: 0.8073 - val_accuracy: 0.7119 - val_precison: 0.7195 - val_recall: 0.6992
# Epoch 11/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.
100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.3017 - accuracy: 0.8923 - precison: 0.8983 - recall: 0.8848 - val_loss: 0.5988 - val_accuracy: 0.7846 - val_precison: 0.7921 - val_recall: 0.7741
# Epoch 29/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.3046 - accuracy: 0.8892 - precison: 0.8956 - recall: 0.8821 - val_loss: 0.5868 - val_accuracy: 0.7885 - val_precison: 0.7958 - val_recall: 0.7799
# Epoch 30/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.3052 - accuracy: 0.8897 - precison: 0.8964 - recall: 0.8823 - val_loss: 0.5835 - val_accuracy: 0.7902 - val_precison: 0.7970 - val_recall: 0.7813
# Epoch 31/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.3043 - accuracy: 0.8901 - precison: 0.8964 - recall: 0.8818 - val_loss: 0.5822 - val_accuracy: 0.7915 - val_precison: 0.7970 - val_recall: 0.7805
# Epoch 32/100
# 431/431 [==============================] - 249s 576ms/step - loss: 0.3033 - accuracy: 0.8887 - precison: 0.8955 - recall: 0.8807 - val_loss: 0.5758 - val_accuracy: 0.7943 - val_precison: 0.7997 - val_recall: 0.7849
# Epoch 33/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.2997 - accuracy: 0.8898 - precison: 0.8972 - recall: 0.8827 - val_loss: 0.5770 - val_accuracy: 0.7951 - val_precison: 0.8003 - val_recall: 0.7844
# Epoch 34/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.2988 - accuracy: 0.8912 - precison: 0.8984 - recall: 0.8836 - val_loss: 0.5724 - val_accuracy: 0.7962 - val_precison: 0.8010 - val_recall: 0.7866
# Epoch 35/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.3000 - accuracy: 0.8909 - precison: 0.8976 - recall: 0.8843 - val_loss: 0.5679 - val_accuracy: 0.7979 - val_precison: 0.8013 - val_recall: 0.7885
# Epoch 36/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.2963 - accuracy: 0.8916 - precison: 0.8970 - recall: 0.8836 - val_loss: 0.5680 - val_accuracy: 0.7968 - val_precison: 0.8020 - val_recall: 0.7882
# Epoch 37/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.3003 - accuracy: 0.8903 - precison: 0.8965 - recall: 0.8832 - val_loss: 0.5634 - val_accuracy: 0.7976 - val_precison: 0.8019 - val_recall: 0.7899
# Epoch 38/100
# 431/431 [==============================] - 249s 576ms/step - loss: 0.3016 - accuracy: 0.8884 - precison: 0.8957 - recall: 0.8821 - val_loss: 0.5574 - val_accuracy: 0.7993 - val_precison: 0.8036 - val_recall: 0.7918
# Epoch 39/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2983 - accuracy: 0.8908 - precison: 0.8972 - recall: 0.8836 - val_loss: 0.5586 - val_accuracy: 0.7982 - val_precison: 0.8038 - val_recall: 0.7918
# Epoch 40/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2990 - accuracy: 0.8931 - precison: 0.8990 - recall: 0.8863 - val_loss: 0.5524 - val_accuracy: 0.8004 - val_precison: 0.8050 - val_recall: 0.7932
# Epoch 41/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2972 - accuracy: 0.8916 - precison: 0.8979 - recall: 0.8840 - val_loss: 0.5518 - val_accuracy: 0.8015 - val_precison: 0.8053 - val_recall: 0.7938
# Epoch 42/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.2975 - accuracy: 0.8923 - precison: 0.8996 - recall: 0.8862 - val_loss: 0.5497 - val_accuracy: 0.8018 - val_precison: 0.8064 - val_recall: 0.7957
# Epoch 43/100
# 431/431 [==============================] - 249s 576ms/step - loss: 0.2934 - accuracy: 0.8925 - precison: 0.8992 - recall: 0.8858 - val_loss: 0.5484 - val_accuracy: 0.8020 - val_precison: 0.8064 - val_recall: 0.7960
# Epoch 44/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.
100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2904 - accuracy: 0.8946 - precison: 0.9003 - recall: 0.8878 - val_loss: 0.5221 - val_accuracy: 0.8126 - val_precison: 0.8178 - val_recall: 0.8040
# Epoch 61/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2876 - accuracy: 0.8953 - precison: 0.9011 - recall: 0.8891 - val_loss: 0.5226 - val_accuracy: 0.8117 - val_precison: 0.8181 - val_recall: 0.8034
# Epoch 62/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2898 - accuracy: 0.8939 - precison: 0.8992 - recall: 0.8868 - val_loss: 0.5218 - val_accuracy: 0.8120 - val_precison: 0.8180 - val_recall: 0.8040
# Epoch 63/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2869 - accuracy: 0.8953 - precison: 0.9013 - recall: 0.8885 - val_loss: 0.5211 - val_accuracy: 0.8134 - val_precison: 0.8174 - val_recall: 0.8045
# Epoch 64/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2871 - accuracy: 0.8953 - precison: 0.9013 - recall: 0.8893 - val_loss: 0.5207 - val_accuracy: 0.8128 - val_precison: 0.8176 - val_recall: 0.8045
# Epoch 65/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2898 - accuracy: 0.8946 - precison: 0.9002 - recall: 0.8882 - val_loss: 0.5217 - val_accuracy: 0.8128 - val_precison: 0.8171 - val_recall: 0.8043
# Epoch 66/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2857 - accuracy: 0.8950 - precison: 0.9009 - recall: 0.8877 - val_loss: 0.5188 - val_accuracy: 0.8128 - val_precison: 0.8183 - val_recall: 0.8043
# Epoch 67/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2895 - accuracy: 0.8946 - precison: 0.9001 - recall: 0.8881 - val_loss: 0.5164 - val_accuracy: 0.8148 - val_precison: 0.8190 - val_recall: 0.8056
# Epoch 68/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2877 - accuracy: 0.8958 - precison: 0.9019 - recall: 0.8896 - val_loss: 0.5170 - val_accuracy: 0.8128 - val_precison: 0.8196 - val_recall: 0.8051
# Epoch 69/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2884 - accuracy: 0.8936 - precison: 0.8999 - recall: 0.8871 - val_loss: 0.5161 - val_accuracy: 0.8128 - val_precison: 0.8188 - val_recall: 0.8059
# Epoch 70/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2878 - accuracy: 0.8936 - precison: 0.9000 - recall: 0.8883 - val_loss: 0.5162 - val_accuracy: 0.8150 - val_precison: 0.8184 - val_recall: 0.8051
# Epoch 71/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.2851 - accuracy: 0.8957 - precison: 0.9022 - recall: 0.8894 - val_loss: 0.5137 - val_accuracy: 0.8156 - val_precison: 0.8203 - val_recall: 0.8062
# Epoch 72/100
# 431/431 [==============================] - 249s 576ms/step - loss: 0.2885 - accuracy: 0.8962 - precison: 0.9012 - recall: 0.8894 - val_loss: 0.5151 - val_accuracy: 0.8156 - val_precison: 0.8193 - val_recall: 0.8059
# Epoch 73/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2863 - accuracy: 0.8945 - precison: 0.9003 - recall: 0.8877 - val_loss: 0.5150 - val_accuracy: 0.8145 - val_precison: 0.8197 - val_recall: 0.8059
# Epoch 74/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.2860 - accuracy: 0.8954 - precison: 0.9017 - recall: 0.8894 - val_loss: 0.5149 - val_accuracy: 0.8148 - val_precison: 0.8198 - val_recall: 0.8065
# Epoch 75/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2864 - accuracy: 0.8949 - precison: 0.9016 - recall: 0.8879 - val_loss: 0.5168 - val_accuracy: 0.8148 - val_precison: 0.8183 - val_recall: 0.8045
# Epoch 76/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2846 - accuracy: 0.8956 - precison: 0.9013 - recall: 0.8888 - val_loss: 0.5126 - val_accuracy: 0.8161 - val_precison: 0.8202 - val_recall: 0.8070
# Epoch 77/100
# 431/431 [==============================] - 249s 578ms/step - loss: 0.2824 - accuracy: 0.8962 - precison: 0.9018 - recall: 0.8902 - val_loss: 0.5126 - val_accuracy: 0.8164 - val_precison: 0.8208 - val_recall: 0.8081
# Epoch 78/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.2850 - accuracy: 0.8966 - precison: 0.9025 - recall: 0.8908 - val_loss: 0.5129 - val_accuracy: 0.8167 - val_precison: 0.8201 - val_recall: 0.8079
# Epoch 79/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.2855 - accuracy: 0.8954 - precison: 0.9020 - recall: 0.8891 - val_loss: 0.5090 - val_accuracy: 0.8173 - val_precison: 0.8205 - val_recall: 0.8101
# Epoch 80/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.2830 - accuracy: 0.8954 - precison: 0.9012 - recall: 0.8895 - val_loss: 0.5121 - val_accuracy: 0.8164 - val_precison: 0.8200 - val_recall: 0.8076
# Epoch 81/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2870 - accuracy: 0.8956 - precison: 0.9012 - recall: 0.8887 - val_loss: 0.5100 - val_accuracy: 0.8173 - val_precison: 0.8202 - val_recall: 0.8098
# Epoch 82/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.2870 - accuracy: 0.8960 - precison: 0.9013 - recall: 0.8893 - val_loss: 0.5084 - val_accuracy: 0.8181 - val_precison: 0.8213 - val_recall: 0.8109
# Epoch 83/100
# 431/431 [==============================] - 249s 576ms/step - loss: 0.2834 - accuracy: 0.8958 - precison: 0.9013 - recall: 0.8892 - val_loss: 0.5108 - val_accuracy: 0.8181 - val_precison: 0.8203 - val_recall: 0.8090
# Epoch 84/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2828 - accuracy: 0.8961 - precison: 0.9017 - recall: 0.8901 - val_loss: 0.5089 - val_accuracy: 0.8181 - val_precison: 0.8217 - val_recall: 0.8106
# Epoch 85/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2854 - accuracy: 0.8957 - precison: 0.9011 - recall: 0.8885 - val_loss: 0.5076 - val_accuracy: 0.8181 - val_precison: 0.8213 - val_recall: 0.8109
# Epoch 86/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.2811 - accuracy: 0.8974 - precison: 0.9026 - recall: 0.8903 - val_loss: 0.5105 - val_accuracy: 0.8178 - val_precison: 0.8194 - val_recall: 0.8079
# Epoch 87/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.2834 - accuracy: 0.8966 - precison: 0.9023 - recall: 0.8905 - val_loss: 0.5078 - val_accuracy: 0.8184 - val_precison: 0.8218 - val_recall: 0.8109
# Epoch 88/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2845 - accuracy: 0.8966 - precison: 0.9022 - recall: 0.8903 - val_loss: 0.5078 - val_accuracy: 0.8184 - val_precison: 0.8212 - val_recall: 0.8103
# Epoch 89/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2831 - accuracy: 0.8952 - precison: 0.9009 - recall: 0.8891 - val_loss: 0.5044 - val_accuracy: 0.8192 - val_precison: 0.8237 - val_recall: 0.8126
# Epoch 90/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2824 - accuracy: 0.8957 - precison: 0.9015 - recall: 0.8906 - val_loss: 0.5053 - val_accuracy: 0.8184 - val_precison: 0.8225 - val_recall: 0.8123
# Epoch 91/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.2813 - accuracy: 0.8994 - precison: 0.9055 - recall: 0.8932 - val_loss: 0.5037 - val_accuracy: 0.8200 - val_precison: 0.8239 - val_recall: 0.8134
# Epoch 92/100
# 431/431 [==============================] - 248s 576ms/step - loss: 0.2834 - accuracy: 0.8966 - precison: 0.9023 - recall: 0.8911 - val_loss: 0.5040 - val_accuracy: 0.8189 - val_precison: 0.8235 - val_recall: 0.8126
# Epoch 93/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2797 - accuracy: 0.8985 - precison: 0.9041 - recall: 0.8923 - val_loss: 0.5060 - val_accuracy: 0.8189 - val_precison: 0.8229 - val_recall: 0.8106
# Epoch 94/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2823 - accuracy: 0.8978 - precison: 0.9030 - recall: 0.8913 - val_loss: 0.5035 - val_accuracy: 0.8208 - val_precison: 0.8239 - val_recall: 0.8137
# Epoch 95/100
# 431/431 [==============================] - 249s 577ms/step - loss: 0.2820 - accuracy: 0.8976 - precison: 0.9027 - recall: 0.8908 - val_loss: 0.5036 - val_accuracy: 0.8195 - val_precison: 0.8238 - val_recall: 0.8128
# Epoch 96/100
# 431/431 [==============================] - 248s 575ms/step - loss: 0.2835 - accuracy: 0.8957 - precison: 0.9017 - recall: 0.8890 - val_loss: 0.5014 - val_accuracy: 0.8208 - val_precison: 0.8245 - val_recall: 0.8142
# Epoch 97/100
# 431/431 [==============================] - 248s 575ms/step - loss: 0.2799 - accuracy: 0.8979 - precison: 0.9033 - recall: 0.8913 - val_loss: 0.5023 - val_accuracy: 0.8211 - val_precison: 0.8237 - val_recall: 0.8137
# Epoch 98/100
# 431/431 [==============================] - 248s 574ms/step - loss: 0.2820 - accuracy: 0.8964 - precison: 0.9025 - recall: 0.8905 - val_loss: 0.5031 - val_accuracy: 0.8206 - val_precison: 0.8233 - val_recall: 0.8117
# Epoch 99/100
# 431/431 [==============================] - 248s 575ms/step - loss: 0.2800 - accuracy: 0.8981 - precison: 0.9031 - recall: 0.8927 - val_loss: 0.5010 - val_accuracy: 0.8211 - val_precison: 0.8244 - val_recall: 0.8139
# Epoch 100/100
# 431/431 [==============================] - 248s 575ms/step - loss: 0.2808 - accuracy: 0.8982 - precison: 0.9037 - recall: 0.8915 - val_loss: 0.5023 - val_accuracy: 0.8203 - val_precison: 0.8238 - val_recall: 0.8128

# %%
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(24, 10))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training accuracy')
    plt.plot(x, val_acc, 'r', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.xlabel('# of epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('# of epochs')
    plt.ylabel('Loss')
    plt.legend()

plot_history(history)

# %%
from keras.models import load_model

saved_model = tf.keras.models.load_model('./XLNet_TASK2_best_model', custom_objects={"TFXLNetModel": TFXLNetModel})

# %%
y_pred = [] 
y_true = [] 

for inputs_id_mask_batch, class_batch in dataset_test:   
   y_true.append(np.argmax(class_batch, axis = -1))
   preds = saved_model.predict(inputs_id_mask_batch)
   y_pred.append(np.argmax(preds, axis = - 1))

correct_labels = tf.concat([item for item in y_true], axis = 0)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)

# %%
cm = confusion_matrix(correct_labels, predicted_labels)

sns.heatmap(cm, annot=True)
plt.title("Confusion Matrix")
plt.ylabel('Correct Values')
plt.xlabel('Predicted Values')
plt.show()
print()
print(classification_report(correct_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80       958
#            1       0.92      0.82      0.87      2367
#            2       0.52      0.74      0.61       292
#
#     accuracy                           0.82      3617
#    macro avg       0.73      0.80      0.76      3617
# weighted avg       0.84      0.82      0.83      3617

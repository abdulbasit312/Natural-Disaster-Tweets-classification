# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/maindatasetfinal2/train_task2.csv
# /kaggle/input/task2bert/task2_test.csv
# /kaggle/input/task2bert/task2_train.csv

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from transformers import DistilBertTokenizerFast, TFDistilBertModel

from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from imblearn.over_sampling import SMOTE
from imblearn.combine import *
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import pandas as pd
import numpy as np
import torch
import keras
import os
import re

# %%
def preprocess(text):
  
  text=text.lower()
  text=re.sub(r'rt\s*@[^:]*:\s', ' ', text)
  text=re.sub(r'[^A-Za-z0-9]+', ' ', text)
  text=re.sub(r' t .*$', '', text)
  text=re.sub(r'\b[a-zA-Z]\b', '', text)
  text=re.sub(r'/^\s+|\s+$|\s+(?=\s)/g', '', text);
  text = re.sub(r's+[a-zA-Z]s+', '', text)
  text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)
  text=re.sub(r'https?','',text)
  text=re.sub(r'#[A-Za-z0-9_]+','',text)
  text=re.sub(r'\.\.\.',' ',text)
  text=text.replace('…',' ')
  text=text.replace('..',' ')
  text=re.sub(r'@\w*',r'',text)
  text=re.sub(r'\s{2,}',r' ',text)
  text=re.sub(r'$[\s]+','',text)
  text=text.replace('&amp','')
  text=text.replace('&gt','')
  text=text.replace('&lt','')
  text=re.sub(r'([\w\d]+)([^\w\d ]+)', r'\1 \2',text)
  text=re.sub(r'([^\w\d ]+)([\w\d]+)', r'\1 \2',text)
 
  return text

# %%
train = pd.read_csv('../input/maindatasetfinal2/train_task2.csv')
train
# Out:
#                                               tweet_text text_human_class  \
# 0      no an undocumented immigrant did not start the...  non_informative
# 1      the massage therapi reaching out to those caug...     humanitarian
# 2       morning meeting we continue to tackle the dam...        structure
# 3      still waiting for my power to come back after ...  non_informative
# 4      floridians with solarpanels were able to get e...  non_informative
# ...                                                  ...              ...
# 27522  last tripadvisor review restaurant in amatrice...        structure
# 27523   drone shows damage around amatrice as rescue ...        structure
# 27524   convent among collapsed buildings in amatrice...        structure
# 27525   the sun ri over collapsed buildings following...        structure
# 27526  satellite pics show ground fallen 20 cms at ac...        structure
#
#        type
# 0         1
# 1         0
# 2         2
# 3         1
# 4         1
# ...     ...
# 27522     2
# 27523     2
# 27524     2
# 27525     2
# 27526     2
#
# [27527 rows x 3 columns]

# %%
test = pd.read_csv('../input/task2bert/task2_test.csv', index_col = 0)
del(test["tweet_id"])
del(test["image_id"])
del(test["image_path"])
del(test["text_info_conf"])
del(test["image_info"])
del(test["image_info_conf"])
del(test["text_human"])
del(test["text_human_conf"])
del(test["image_human"])
del(test["image_human_conf"])
del(test["image_damage"])
del(test["image_damage_conf"])
del(test["image_url"])
del(test["Unnamed: 0.1"])
del(test["image_human_class"])
del(test["text_info"])

test["tweet_text"]=test["tweet_text"].apply(lambda x: preprocess(x))
test["type"] = test["text_human_class"].apply(lambda x: 0 if x == "humanitarian" else 1 if x == "non_informative" else 2)

test
# Out:
#                                               tweet_text text_human_class  \
# 11755  selling popcorn at lunch to benefit victims of...     humanitarian
# 1157   not only california northern spain amp portuga...  non_informative
# 16557  5pm tuesday tropical update maria still catego...  non_informative
# 7679   3 scenes of landsat ingested to hdds for event...  non_informative
# 196     realomarnavarro schnauzermom777 can you stop ...  non_informative
# ...                                                  ...              ...
# 2888                my town in pr after hurricane maria   non_informative
# 8619    stiletto in texas it more than shoe it an att...  non_informative
# 16509  help our members affected by harvey and irma d...     humanitarian
# 1418   california wine country wildfires near contain...  non_informative
# 91     playing with my new friend chai she california...  non_informative
#
#        type
# 11755     0
# 1157      1
# 16557     1
# 7679      1
# 196       1
# ...     ...
# 2888      1
# 8619      1
# 16509     0
# 1418      1
# 91        1
#
# [3617 rows x 3 columns]

# %%
train["type"].value_counts()
# Out:
# 0    9549
# 1    9305
# 2    8673
# Name: type, dtype: int64

# %%
tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')
distilbert = TFDistilBertModel.from_pretrained('distilbert-base-uncased', output_hidden_states = True)
# Out:
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertModel: ['vocab_projector', 'vocab_layer_norm', 'activation_13', 'vocab_transform']
# - This IS expected if you are initializing TFDistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFDistilBertModel were initialized from the model checkpoint at distilbert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertModel for predictions without further training.

# %%
tokenized_train = train["tweet_text"].apply((lambda x: tokenizer.encode(x, add_special_tokens=True, max_length=60)))
tokenized_test = test["tweet_text"].apply((lambda x: tokenizer.encode(x, add_special_tokens=True, max_length=60)))
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
max_len = 0

for i in tokenized_train.values:
    if len(i) > max_len:
        max_len = len(i)
max_len
# Out:
# 60

# %%
input_ids_train= np.array([i + [0]*(max_len-len(i)) for i in tokenized_train.values])
attention_mask_train= np.where(input_ids_train!= 0, 1, 0)

input_ids_test= np.array([i + [0]*(max_len-len(i)) for i in tokenized_test.values])
attention_mask_test=np.where(input_ids_test!= 0, 1, 0)

# %%
arr_train = train["type"].values
arr_test = test["type"].values

num_samples_train = len(train)
num_samples_test = len(test)

labels_train = np.zeros((num_samples_train, arr_train.max()+1))
labels_test = np.zeros((num_samples_test, arr_test.max()+1))

labels_train[np.arange(num_samples_train), arr_train] = 1
labels_test[np.arange(num_samples_test), arr_test] = 1

# %%
dataset_train = tf.data.Dataset.from_tensor_slices((input_ids_train,attention_mask_train,labels_train))
dataset_test = tf.data.Dataset.from_tensor_slices((input_ids_test,attention_mask_test,labels_test))

def map_func(input_ids, masks, labels):
    return {'input_ids' : input_ids, 'attention_mask' : masks}, labels

dataset_train = dataset_train.map(map_func)
dataset_test = dataset_test.map(map_func)

# %%
dataset_train = dataset_train.shuffle(4800)

dataset_train = dataset_train.batch(128)
dataset_test = dataset_test.batch(8)

# %%
input_ids = tf.keras.layers.Input(shape=(max_len,), name = "input_ids", dtype = 'int32')
mask = tf.keras.layers.Input(shape=(max_len,), name = "attention_mask", dtype = 'int32')

embeddings = distilbert(input_ids, attention_mask=mask)
hidden_layers = embeddings[0]

#cls_token = hidden_layers[:, 0, :]
#conc_layer1 = hidden_layers[-4]
#conc_layer2 = hidden_layers[-3]
#conc_layer3 = hidden_layers[-2]
#conc_layer4 = hidden_layers[-1]

#conc = tf.keras.layers.Concatenate()([conc_layer1, conc_layer2, conc_layer3, conc_layer4])

cod = tf.keras.layers.LSTM(256, return_sequences = True)(hidden_layers)
cod = tf.keras.layers.Dropout(0.2)(cod)
cod = tf.keras.layers.LSTM(128)(cod)
cod = tf.keras.layers.Dropout(0.2)(cod)
cod = tf.keras.layers.Dense(64)(cod)
cod = tf.keras.layers.Dropout(0.2)(cod)

y = tf.keras.layers.Dense(3, activation="softmax", name="outputs")(cod)

# %%
model = tf.keras.Model(inputs = [input_ids, mask], outputs = [y])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-5, decay = 0.01)
loss = tf.keras.losses.CategoricalCrossentropy()
metrics = METRICS = [
    tf.keras.metrics.CategoricalAccuracy(name="accuracy"),
    tf.keras.metrics.Precision(name="precison"),
    tf.keras.metrics.Recall(name="recall")
]

es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
mc = keras.callbacks.ModelCheckpoint('/kaggle/working/best_model_DISTIL_task2-CLS.h5', monitor='val_loss', mode='min', verbose = 1, save_best_only=True)

#class_weights = {1: 0.1288,
#                0: 0.3084,
#                2: 1.0072}

model.compile(optimizer=optimizer, loss = loss, metrics = metrics)

# %%
history = model.fit(
    dataset_train,
    validation_data = dataset_test,
    epochs = 100,
    callbacks=[es,mc]
)
# Out:
# Epoch 1/100
# 2022-05-17 16:08:16.556428: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-05-17 16:08:19.538833: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 216/216 [==============================] - 116s 486ms/step - loss: 0.4874 - accuracy: 0.8201 - precison: 0.8455 - recall: 0.7874 - val_loss: 0.8918 - val_accuracy: 0.6821 - val_precison: 0.6971 - val_recall: 0.6566
#
# Epoch 00001: val_loss improved from inf to 0.89175, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 2/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.3320 - accuracy: 0.8857 - precison: 0.8919 - recall: 0.8787 - val_loss: 0.8186 - val_accuracy: 0.7141 - val_precison: 0.7265 - val_recall: 0.6962
#
# Epoch 00002: val_loss improved from 0.89175 to 0.81865, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 3/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.3180 - accuracy: 0.8889 - precison: 0.8949 - recall: 0.8820 - val_loss: 0.7972 - val_accuracy: 0.7161 - val_precison: 0.7287 - val_recall: 0.6945
#
# Epoch 00003: val_loss improved from 0.81865 to 0.79718, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 4/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.3061 - accuracy: 0.8916 - precison: 0.8978 - recall: 0.8848 - val_loss: 0.7704 - val_accuracy: 0.7271 - val_precison: 0.7387 - val_recall: 0.7058
#
# Epoch 00004: val_loss improved from 0.79718 to 0.77039, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 5/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.3038 - accuracy: 0.8915 - precison: 0.8974 - recall: 0.8845 - val_loss: 0.7368 - val_accuracy: 0.7376 - val_precison: 0.7483 - val_recall: 0.7183
#
# Epoch 00005: val_loss improved from 0.77039 to 0.73677, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 6/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2976 - accuracy: 0.8938 - precison: 0.9001 - recall: 0.8869 - val_loss: 0.6976 - val_accuracy: 0.7526 - val_precison: 0.7625 - val_recall: 0.7376
#
# Epoch 00006: val_loss improved from 0.73677 to 0.69757, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 7/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2968 - accuracy: 0.8940 - precison: 0.8998 - recall: 0.8868 - val_loss: 0.6828 - val_accuracy: 0.7570 - val_precison: 0.7668 - val_recall: 0.7429
#
# Epoch 00007: val_loss improved from 0.69757 to 0.68281, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 8/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2959 - accuracy: 0.8924 - precison: 0.8984 - recall: 0.8864 - val_loss: 0.6288 - val_accuracy: 0.7727 - val_precison: 0.7805 - val_recall: 0.7617
#
# Epoch 00008: val_loss improved from 0.68281 to 0.62885, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 9/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2932 - accuracy: 0.8958 - precison: 0.9015 - recall: 0.8896 - val_loss: 0.6176 - val_accuracy: 0.7763 - val_precison: 0.7844 - val_recall: 0.7653
#
# Epoch 00009: val_loss improved from 0.62885 to 0.61757, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 10/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2887 - accuracy: 0.8968 - precison: 0.9024 - recall: 0.8902 - val_loss: 0.6020 - val_accuracy: 0.7810 - val_precison: 0.7891 - val_recall: 0.7697
#
# Epoch 00010: val_loss improved from 0.61757 to 0.60196, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 11/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2894 - accuracy: 0.8952 - precison: 0.9015 - recall: 0.8895 - val_loss: 0.5869 - val_accuracy: 0.7860 - val_precison: 0.7945 - val_recall: 0.7738
#
# Epoch 00011: val_loss improved from 0.60196 to 0.58686, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 12/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2867 - accuracy: 0.8986 - precison: 0.9040 - recall: 0.8917 - val_loss: 0.5685 - val_accuracy: 0.7910 - val_precison: 0.8005 - val_recall: 0.7797
#
# Epoch 00012: val_loss improved from 0.58686 to 0.56846, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 13/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2847 - accuracy: 0.8973 - precison: 0.9028 - recall: 0.8905 - val_loss: 0.5616 - val_accuracy: 0.7924 - val_precison: 0.8028 - val_recall: 0.7832
#
# Epoch 00013: val_loss improved from 0.56846 to 0.56157, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 14/100
# 216/216 [==============================] - 102s 471ms/step - loss: 0.2818 - accuracy: 0.8980 - precison: 0.9044 - recall: 0.8906 - val_loss: 0.5506 - val_accuracy: 0.7968 - val_precison: 0.8050 - val_recall: 0.7863
#
# Epoch 00014: val_loss improved from 0.56157 to 0.55064, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 15/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2815 - accuracy: 0.8996 - precison: 0.9052 - recall: 0.8928 - val_loss: 0.5401 - val_accuracy: 0.8009 - val_precison: 0.8095 - val_recall: 0.7918
#
# Epoch 00015: val_loss improved from 0.55064 to 0.54012, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 16/100
# 216/216 [==============================] - 103s 474ms/step - loss: 0.2784 - accuracy: 0.9004 - precison: 0.9063 - recall: 0.8949 - val_loss: 0.5338 - val_accuracy: 0.8034 - val_precison: 0.8115 - val_recall: 0.7951
#
# Epoch 00016: val_loss improved from 0.54012 to 0.53383, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 17/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2758 - accuracy: 0.9012 - precison: 0.9069 - recall: 0.8953 - val_loss: 0.5302 - val_accuracy: 0.8054 - val_precison: 0.8119 - val_recall: 0.7971
#
# Epoch 00017: val_loss improved from 0.53383 to 0.53022, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 18/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2759 - accuracy: 0.9012 - precison: 0.9065 - recall: 0.8950 - val_loss: 0.5188 - val_accuracy: 0.8076 - val_precison: 0.8152 - val_recall: 0.7987
#
# Epoch 00018: val_loss improved from 0.53022 to 0.51881, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 19/100
# 216/216 [==============================] - 103s 476ms/step - loss: 0.2739 - accuracy: 0.9022 - precison: 0.9070 - recall: 0.8953 - val_loss: 0.5183 - val_accuracy: 0.8081 - val_precison: 0.8136 - val_recall: 0.7990
#
# Epoch 00019: val_loss improved from 0.51881 to 0.51827, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 20/100
# 216/216 [==============================] - 103s 474ms/step - loss: 0.2719 - accuracy: 0.9031 - precison: 0.9083 - recall: 0.8975 - val_loss: 0.5128 - val_accuracy: 0.8090 - val_precison: 0.8166 - val_recall: 0.8001
#
# Epoch 00020: val_loss improved from 0.51827 to 0.51281, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 21/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2681 - accuracy: 0.9037 - precison: 0.9094 - recall: 0.8982 - val_loss: 0.5082 - val_accuracy: 0.8114 - val_precison: 0.8190 - val_recall: 0.8020
#
# Epoch 00021: val_loss improved from 0.51281 to 0.50819, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 22/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2689 - accuracy: 0.9031 - precison: 0.9088 - recall: 0.8977 - val_loss: 0.5038 - val_accuracy: 0.8128 - val_precison: 0.8211 - val_recall: 0.8034
#
# Epoch 00022: val_loss improved from 0.50819 to 0.50382, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 23/100
# 216/216 [==============================] - 103s 476ms/step - loss: 0.2705 - accuracy: 0.9048 - precison: 0.9100 - recall: 0.8988 - val_loss: 0.5007 - val_accuracy: 0.8150 - val_precison: 0.8236 - val_recall: 0.8054
#
# Epoch 00023: val_loss improved from 0.50382 to 0.50071, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 24/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2677 - accuracy: 0.9047 - precison: 0.9098 - recall: 0.8990 - val_loss: 0.4958 - val_accuracy: 0.8173 - val_precison: 0.8255 - val_recall: 0.8095
#
# Epoch 00024: val_loss improved from 0.50071 to 0.49579, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 25/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2659 - accuracy: 0.9050 - precison: 0.9099 - recall: 0.8991 - val_loss: 0.4959 - val_accuracy: 0.8178 - val_precison: 0.8258 - val_recall: 0.8098
#
# Epoch 00025: val_loss did not improve from 0.49579
# Epoch 26/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2676 - accuracy: 0.9040 - precison: 0.9095 - recall: 0.8986 - val_loss: 0.4903 - val_accuracy: 0.8208 - val_precison: 0.8277 - val_recall: 0.8126
#
# Epoch 00026: val_loss improved from 0.49579 to 0.49028, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 27/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2650 - accuracy: 0.9060 - precison: 0.9106 - recall: 0.9006 - val_loss: 0.4906 - val_accuracy: 0.8206 - val_precison: 0.8281 - val_recall: 0.8123
#
# Epoch 00027: val_loss did not improve from 0.49028
# Epoch 28/100
# 216/216 [==============================] - 102s 474ms/step - loss: 0.2654 - accuracy: 0.9053 - precison: 0.9100 - recall: 0.9003 - val_loss: 0.4850 - val_accuracy: 0.8231 - val_precison: 0.8286 - val_recall: 0.8153
#
# Epoch 00028: val_loss improved from 0.49028 to 0.48498, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 29/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2626 - accuracy: 0.9049 - precison: 0.9102 - recall: 0.8994 - val_loss: 0.4834 - val_accuracy: 0.8242 - val_precison: 0.8287 - val_recall: 0.8156
#
# Epoch 00029: val_loss improved from 0.48498 to 0.48343, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 30/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2621 - accuracy: 0.9069 - precison: 0.9123 - recall: 0.9010 - val_loss: 0.4794 - val_accuracy: 0.8253 - val_precison: 0.8296 - val_recall: 0.8173
#
# Epoch 00030: val_loss improved from 0.48343 to 0.47942, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 31/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2605 - accuracy: 0.9086 - precison: 0.9132 - recall: 0.9029 - val_loss: 0.4797 - val_accuracy: 0.8255 - val_precison: 0.8296 - val_recall: 0.8173
#
# Epoch 00031: val_loss did not improve from 0.47942
# Epoch 32/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2598 - accuracy: 0.9078 - precison: 0.9124 - recall: 0.9023 - val_loss: 0.4828 - val_accuracy: 0.8239 - val_precison: 0.8288 - val_recall: 0.8137
#
# Epoch 00032: val_loss did not improve from 0.47942
# Epoch 33/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2575 - accuracy: 0.9082 - precison: 0.9131 - recall: 0.9029 - val_loss: 0.4774 - val_accuracy: 0.8267 - val_precison: 0.8308 - val_recall: 0.8161
#
# Epoch 00033: val_loss improved from 0.47942 to 0.47738, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 34/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2599 - accuracy: 0.9074 - precison: 0.9122 - recall: 0.9020 - val_loss: 0.4770 - val_accuracy: 0.8267 - val_precison: 0.8309 - val_recall: 0.8153
#
# Epoch 00034: val_loss improved from 0.47738 to 0.47698, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 35/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2574 - accuracy: 0.9078 - precison: 0.9126 - recall: 0.9027 - val_loss: 0.4745 - val_accuracy: 0.8275 - val_precison: 0.8313 - val_recall: 0.8175
#
# Epoch 00035: val_loss improved from 0.47698 to 0.47446, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 36/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2581 - accuracy: 0.9087 - precison: 0.9133 - recall: 0.9027 - val_loss: 0.4735 - val_accuracy: 0.8275 - val_precison: 0.8317 - val_recall: 0.8184
#
# Epoch 00036: val_loss improved from 0.47446 to 0.47355, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 37/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2577 - accuracy: 0.9087 - precison: 0.9137 - recall: 0.9034 - val_loss: 0.4737 - val_accuracy: 0.8272 - val_precison: 0.8320 - val_recall: 0.8186
#
# Epoch 00037: val_loss did not improve from 0.47355
# Epoch 38/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2554 - accuracy: 0.9098 - precison: 0.9145 - recall: 0.9045 - val_loss: 0.4716 - val_accuracy: 0.8280 - val_precison: 0.8316 - val_recall: 0.8192
#
# Epoch 00038: val_loss improved from 0.47355 to 0.47165, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 39/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2548 - accuracy: 0.9085 - precison: 0.9135 - recall: 0.9026 - val_loss: 0.4714 - val_accuracy: 0.8283 - val_precison: 0.8316 - val_recall: 0.8195
#
# Epoch 00039: val_loss improved from 0.47165 to 0.47137, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 40/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2548 - accuracy: 0.9101 - precison: 0.9154 - recall: 0.9046 - val_loss: 0.4701 - val_accuracy: 0.8283 - val_precison: 0.8326 - val_recall: 0.8197
#
# Epoch 00040: val_loss improved from 0.47137 to 0.47005, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 41/100
# 216/216 [==============================] - 103s 474ms/step - loss: 0.2531 - accuracy: 0.9106 - precison: 0.9151 - recall: 0.9067 - val_loss: 0.4689 - val_accuracy: 0.8289 - val_precison: 0.8334 - val_recall: 0.8200
#
# Epoch 00041: val_loss improved from 0.47005 to 0.46893, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 42/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2522 - accuracy: 0.9101 - precison: 0.9140 - recall: 0.9046 - val_loss: 0.4673 - val_accuracy: 0.8291 - val_precison: 0.8344 - val_recall: 0.8192
#
# Epoch 00042: val_loss improved from 0.46893 to 0.46731, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 43/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2517 - accuracy: 0.9110 - precison: 0.9149 - recall: 0.9059 - val_loss: 0.4680 - val_accuracy: 0.8297 - val_precison: 0.8342 - val_recall: 0.8206
#
# Epoch 00043: val_loss did not improve from 0.46731
# Epoch 44/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2505 - accuracy: 0.9104 - precison: 0.9151 - recall: 0.9058 - val_loss: 0.4664 - val_accuracy: 0.8294 - val_precison: 0.8345 - val_recall: 0.8208
#
# Epoch 00044: val_loss improved from 0.46731 to 0.46642, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 45/100
# 216/216 [==============================] - 103s 474ms/step - loss: 0.2509 - accuracy: 0.9105 - precison: 0.9144 - recall: 0.9053 - val_loss: 0.4669 - val_accuracy: 0.8294 - val_precison: 0.8333 - val_recall: 0.8211
#
# Epoch 00045: val_loss did not improve from 0.46642
# Epoch 46/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2501 - accuracy: 0.9114 - precison: 0.9155 - recall: 0.9061 - val_loss: 0.4662 - val_accuracy: 0.8291 - val_precison: 0.8344 - val_recall: 0.8203
#
# Epoch 00046: val_loss improved from 0.46642 to 0.46621, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 47/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2500 - accuracy: 0.9113 - precison: 0.9153 - recall: 0.9062 - val_loss: 0.4639 - val_accuracy: 0.8297 - val_precison: 0.8349 - val_recall: 0.8208
#
# Epoch 00047: val_loss improved from 0.46621 to 0.46393, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 48/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2488 - accuracy: 0.9118 - precison: 0.9162 - recall: 0.9075 - val_loss: 0.4635 - val_accuracy: 0.8300 - val_precison: 0.8354 - val_recall: 0.8211
#
# Epoch 00048: val_loss improved from 0.46393 to 0.46350, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 49/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2489 - accuracy: 0.9098 - precison: 0.9143 - recall: 0.9049 - val_loss: 0.4611 - val_accuracy: 0.8311 - val_precison: 0.8355 - val_recall: 0.8231
#
# Epoch 00049: val_loss improved from 0.46350 to 0.46106, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 50/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2493 - accuracy: 0.9108 - precison: 0.9157 - recall: 0.9049 - val_loss: 0.4640 - val_accuracy: 0.8305 - val_precison: 0.8350 - val_recall: 0.8214
#
# Epoch 00050: val_loss did not improve from 0.46106
# Epoch 51/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2479 - accuracy: 0.9108 - precison: 0.9157 - recall: 0.9059 - val_loss: 0.4634 - val_accuracy: 0.8311 - val_precison: 0.8350 - val_recall: 0.8214
#
# Epoch 00051: val_loss did not improve from 0.46106
# Epoch 52/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2479 - accuracy: 0.9119 - precison: 0.9170 - recall: 0.9071 - val_loss: 0.4624 - val_accuracy: 0.8316 - val_precison: 0.8355 - val_recall: 0.8228
#
# Epoch 00052: val_loss did not improve from 0.46106
# Epoch 53/100
# 216/216 [==============================] - 103s 474ms/step - loss: 0.2439 - accuracy: 0.9132 - precison: 0.9170 - recall: 0.9084 - val_loss: 0.4616 - val_accuracy: 0.8319 - val_precison: 0.8356 - val_recall: 0.8236
#
# Epoch 00053: val_loss did not improve from 0.46106
# Epoch 54/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2477 - accuracy: 0.9113 - precison: 0.9161 - recall: 0.9068 - val_loss: 0.4605 - val_accuracy: 0.8311 - val_precison: 0.8359 - val_recall: 0.8236
#
# Epoch 00054: val_loss improved from 0.46106 to 0.46045, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 55/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2441 - accuracy: 0.9130 - precison: 0.9180 - recall: 0.9076 - val_loss: 0.4607 - val_accuracy: 0.8311 - val_precison: 0.8360 - val_recall: 0.8233
#
# Epoch 00055: val_loss did not improve from 0.46045
# Epoch 56/100
# 216/216 [==============================] - 102s 474ms/step - loss: 0.2481 - accuracy: 0.9121 - precison: 0.9169 - recall: 0.9071 - val_loss: 0.4593 - val_accuracy: 0.8314 - val_precison: 0.8357 - val_recall: 0.8239
#
# Epoch 00056: val_loss improved from 0.46045 to 0.45925, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 57/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2441 - accuracy: 0.9134 - precison: 0.9174 - recall: 0.9087 - val_loss: 0.4585 - val_accuracy: 0.8316 - val_precison: 0.8359 - val_recall: 0.8239
#
# Epoch 00057: val_loss improved from 0.45925 to 0.45851, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 58/100
# 216/216 [==============================] - 102s 471ms/step - loss: 0.2447 - accuracy: 0.9131 - precison: 0.9177 - recall: 0.9079 - val_loss: 0.4579 - val_accuracy: 0.8314 - val_precison: 0.8362 - val_recall: 0.8242
#
# Epoch 00058: val_loss improved from 0.45851 to 0.45791, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 59/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2438 - accuracy: 0.9150 - precison: 0.9193 - recall: 0.9104 - val_loss: 0.4585 - val_accuracy: 0.8322 - val_precison: 0.8357 - val_recall: 0.8242
#
# Epoch 00059: val_loss did not improve from 0.45791
# Epoch 60/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2440 - accuracy: 0.9139 - precison: 0.9182 - recall: 0.9092 - val_loss: 0.4581 - val_accuracy: 0.8322 - val_precison: 0.8358 - val_recall: 0.8247
#
# Epoch 00060: val_loss did not improve from 0.45791
# Epoch 61/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2428 - accuracy: 0.9139 - precison: 0.9179 - recall: 0.9090 - val_loss: 0.4576 - val_accuracy: 0.8322 - val_precison: 0.8366 - val_recall: 0.8250
#
# Epoch 00061: val_loss improved from 0.45791 to 0.45757, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 62/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2425 - accuracy: 0.9142 - precison: 0.9189 - recall: 0.9087 - val_loss: 0.4577 - val_accuracy: 0.8316 - val_precison: 0.8366 - val_recall: 0.8250
#
# Epoch 00062: val_loss did not improve from 0.45757
# Epoch 63/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2435 - accuracy: 0.9134 - precison: 0.9179 - recall: 0.9082 - val_loss: 0.4567 - val_accuracy: 0.8325 - val_precison: 0.8368 - val_recall: 0.8250
#
# Epoch 00063: val_loss improved from 0.45757 to 0.45668, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 64/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2442 - accuracy: 0.9138 - precison: 0.9180 - recall: 0.9091 - val_loss: 0.4569 - val_accuracy: 0.8325 - val_precison: 0.8372 - val_recall: 0.8258
#
# Epoch 00064: val_loss did not improve from 0.45668
# Epoch 65/100
# 216/216 [==============================] - 102s 474ms/step - loss: 0.2429 - accuracy: 0.9143 - precison: 0.9191 - recall: 0.9096 - val_loss: 0.4557 - val_accuracy: 0.8333 - val_precison: 0.8367 - val_recall: 0.8247
#
# Epoch 00065: val_loss improved from 0.45668 to 0.45567, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 66/100
# 216/216 [==============================] - 102s 471ms/step - loss: 0.2441 - accuracy: 0.9136 - precison: 0.9179 - recall: 0.9089 - val_loss: 0.4550 - val_accuracy: 0.8327 - val_precison: 0.8368 - val_recall: 0.8253
#
# Epoch 00066: val_loss improved from 0.45567 to 0.45496, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 67/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2409 - accuracy: 0.9147 - precison: 0.9195 - recall: 0.9105 - val_loss: 0.4553 - val_accuracy: 0.8330 - val_precison: 0.8374 - val_recall: 0.8255
#
# Epoch 00067: val_loss did not improve from 0.45496
# Epoch 68/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2395 - accuracy: 0.9145 - precison: 0.9191 - recall: 0.9098 - val_loss: 0.4554 - val_accuracy: 0.8330 - val_precison: 0.8374 - val_recall: 0.8258
#
# Epoch 00068: val_loss did not improve from 0.45496
# Epoch 69/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2400 - accuracy: 0.9145 - precison: 0.9188 - recall: 0.9096 - val_loss: 0.4550 - val_accuracy: 0.8333 - val_precison: 0.8381 - val_recall: 0.8255
#
# Epoch 00069: val_loss did not improve from 0.45496
# Epoch 70/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2378 - accuracy: 0.9150 - precison: 0.9193 - recall: 0.9105 - val_loss: 0.4548 - val_accuracy: 0.8330 - val_precison: 0.8373 - val_recall: 0.8253
#
# Epoch 00070: val_loss improved from 0.45496 to 0.45480, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 71/100
# 216/216 [==============================] - 102s 474ms/step - loss: 0.2403 - accuracy: 0.9152 - precison: 0.9197 - recall: 0.9102 - val_loss: 0.4544 - val_accuracy: 0.8325 - val_precison: 0.8372 - val_recall: 0.8258
#
# Epoch 00071: val_loss improved from 0.45480 to 0.45443, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 72/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2390 - accuracy: 0.9155 - precison: 0.9197 - recall: 0.9104 - val_loss: 0.4531 - val_accuracy: 0.8330 - val_precison: 0.8372 - val_recall: 0.8261
#
# Epoch 00072: val_loss improved from 0.45443 to 0.45309, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 73/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2390 - accuracy: 0.9163 - precison: 0.9197 - recall: 0.9110 - val_loss: 0.4540 - val_accuracy: 0.8333 - val_precison: 0.8376 - val_recall: 0.8255
#
# Epoch 00073: val_loss did not improve from 0.45309
# Epoch 74/100
# 216/216 [==============================] - 103s 474ms/step - loss: 0.2381 - accuracy: 0.9154 - precison: 0.9198 - recall: 0.9105 - val_loss: 0.4538 - val_accuracy: 0.8330 - val_precison: 0.8375 - val_recall: 0.8253
#
# Epoch 00074: val_loss did not improve from 0.45309
# Epoch 75/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2402 - accuracy: 0.9147 - precison: 0.9188 - recall: 0.9101 - val_loss: 0.4525 - val_accuracy: 0.8333 - val_precison: 0.8369 - val_recall: 0.8255
#
# Epoch 00075: val_loss improved from 0.45309 to 0.45252, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 76/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2389 - accuracy: 0.9140 - precison: 0.9186 - recall: 0.9090 - val_loss: 0.4529 - val_accuracy: 0.8330 - val_precison: 0.8369 - val_recall: 0.8258
#
# Epoch 00076: val_loss did not improve from 0.45252
# Epoch 77/100
# 216/216 [==============================] - 103s 474ms/step - loss: 0.2383 - accuracy: 0.9146 - precison: 0.9194 - recall: 0.9099 - val_loss: 0.4528 - val_accuracy: 0.8333 - val_precison: 0.8374 - val_recall: 0.8255
#
# Epoch 00077: val_loss did not improve from 0.45252
# Epoch 78/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2363 - accuracy: 0.9170 - precison: 0.9216 - recall: 0.9115 - val_loss: 0.4524 - val_accuracy: 0.8333 - val_precison: 0.8375 - val_recall: 0.8253
#
# Epoch 00078: val_loss improved from 0.45252 to 0.45237, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 79/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2372 - accuracy: 0.9156 - precison: 0.9202 - recall: 0.9116 - val_loss: 0.4530 - val_accuracy: 0.8333 - val_precison: 0.8378 - val_recall: 0.8255
#
# Epoch 00079: val_loss did not improve from 0.45237
# Epoch 80/100
# 216/216 [==============================] - 103s 474ms/step - loss: 0.2398 - accuracy: 0.9152 - precison: 0.9203 - recall: 0.9107 - val_loss: 0.4527 - val_accuracy: 0.8327 - val_precison: 0.8378 - val_recall: 0.8255
#
# Epoch 00080: val_loss did not improve from 0.45237
# Epoch 81/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2348 - accuracy: 0.9167 - precison: 0.9211 - recall: 0.9123 - val_loss: 0.4529 - val_accuracy: 0.8322 - val_precison: 0.8378 - val_recall: 0.8255
#
# Epoch 00081: val_loss did not improve from 0.45237
# Epoch 82/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2376 - accuracy: 0.9164 - precison: 0.9202 - recall: 0.9116 - val_loss: 0.4539 - val_accuracy: 0.8333 - val_precison: 0.8378 - val_recall: 0.8253
#
# Epoch 00082: val_loss did not improve from 0.45237
# Epoch 83/100
# 216/216 [==============================] - 102s 472ms/step - loss: 0.2351 - accuracy: 0.9188 - precison: 0.9231 - recall: 0.9134 - val_loss: 0.4534 - val_accuracy: 0.8330 - val_precison: 0.8379 - val_recall: 0.8258
#
# Epoch 00083: val_loss did not improve from 0.45237
# Epoch 84/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2347 - accuracy: 0.9159 - precison: 0.9201 - recall: 0.9106 - val_loss: 0.4526 - val_accuracy: 0.8330 - val_precison: 0.8378 - val_recall: 0.8253
#
# Epoch 00084: val_loss did not improve from 0.45237
# Epoch 85/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2355 - accuracy: 0.9169 - precison: 0.9208 - recall: 0.9117 - val_loss: 0.4533 - val_accuracy: 0.8330 - val_precison: 0.8378 - val_recall: 0.8255
#
# Epoch 00085: val_loss did not improve from 0.45237
# Epoch 86/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2355 - accuracy: 0.9165 - precison: 0.9211 - recall: 0.9119 - val_loss: 0.4521 - val_accuracy: 0.8325 - val_precison: 0.8380 - val_recall: 0.8250
#
# Epoch 00086: val_loss improved from 0.45237 to 0.45209, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 87/100
# 216/216 [==============================] - 103s 474ms/step - loss: 0.2342 - accuracy: 0.9176 - precison: 0.9217 - recall: 0.9125 - val_loss: 0.4530 - val_accuracy: 0.8336 - val_precison: 0.8378 - val_recall: 0.8255
#
# Epoch 00087: val_loss did not improve from 0.45209
# Epoch 88/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2334 - accuracy: 0.9170 - precison: 0.9213 - recall: 0.9128 - val_loss: 0.4516 - val_accuracy: 0.8330 - val_precison: 0.8384 - val_recall: 0.8261
#
# Epoch 00088: val_loss improved from 0.45209 to 0.45159, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 89/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2355 - accuracy: 0.9154 - precison: 0.9202 - recall: 0.9109 - val_loss: 0.4513 - val_accuracy: 0.8316 - val_precison: 0.8375 - val_recall: 0.8250
#
# Epoch 00089: val_loss improved from 0.45159 to 0.45132, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 90/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2331 - accuracy: 0.9177 - precison: 0.9214 - recall: 0.9132 - val_loss: 0.4525 - val_accuracy: 0.8330 - val_precison: 0.8378 - val_recall: 0.8253
#
# Epoch 00090: val_loss did not improve from 0.45132
# Epoch 91/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2330 - accuracy: 0.9177 - precison: 0.9219 - recall: 0.9124 - val_loss: 0.4516 - val_accuracy: 0.8322 - val_precison: 0.8382 - val_recall: 0.8253
#
# Epoch 00091: val_loss did not improve from 0.45132
# Epoch 92/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2346 - accuracy: 0.9158 - precison: 0.9208 - recall: 0.9117 - val_loss: 0.4515 - val_accuracy: 0.8314 - val_precison: 0.8381 - val_recall: 0.8255
#
# Epoch 00092: val_loss did not improve from 0.45132
# Epoch 93/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2345 - accuracy: 0.9176 - precison: 0.9216 - recall: 0.9129 - val_loss: 0.4509 - val_accuracy: 0.8327 - val_precison: 0.8385 - val_recall: 0.8253
#
# Epoch 00093: val_loss improved from 0.45132 to 0.45093, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 94/100
# 216/216 [==============================] - 103s 474ms/step - loss: 0.2334 - accuracy: 0.9183 - precison: 0.9222 - recall: 0.9135 - val_loss: 0.4504 - val_accuracy: 0.8319 - val_precison: 0.8387 - val_recall: 0.8250
#
# Epoch 00094: val_loss improved from 0.45093 to 0.45038, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 95/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2321 - accuracy: 0.9182 - precison: 0.9222 - recall: 0.9131 - val_loss: 0.4499 - val_accuracy: 0.8316 - val_precison: 0.8371 - val_recall: 0.8242
#
# Epoch 00095: val_loss improved from 0.45038 to 0.44985, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 96/100
# 216/216 [==============================] - 103s 474ms/step - loss: 0.2332 - accuracy: 0.9180 - precison: 0.9223 - recall: 0.9136 - val_loss: 0.4512 - val_accuracy: 0.8322 - val_precison: 0.8387 - val_recall: 0.8250
#
# Epoch 00096: val_loss did not improve from 0.44985
# Epoch 97/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2337 - accuracy: 0.9174 - precison: 0.9213 - recall: 0.9130 - val_loss: 0.4501 - val_accuracy: 0.8319 - val_precison: 0.8379 - val_recall: 0.8247
#
# Epoch 00097: val_loss did not improve from 0.44985
# Epoch 98/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2320 - accuracy: 0.9175 - precison: 0.9221 - recall: 0.9132 - val_loss: 0.4500 - val_accuracy: 0.8311 - val_precison: 0.8374 - val_recall: 0.8244
#
# Epoch 00098: val_loss did not improve from 0.44985
# Epoch 99/100
# 216/216 [==============================] - 102s 473ms/step - loss: 0.2322 - accuracy: 0.9180 - precison: 0.9225 - recall: 0.9122 - val_loss: 0.4496 - val_accuracy: 0.8316 - val_precison: 0.8381 - val_recall: 0.8244
#
# Epoch 00099: val_loss improved from 0.44985 to 0.44960, saving model to /kaggle/working/best_model_DISTIL_task2-CLS.h5
# Epoch 100/100
# 216/216 [==============================] - 103s 475ms/step - loss: 0.2316 - accuracy: 0.9184 - precison: 0.9221 - recall: 0.9136 - val_loss: 0.4497 - val_accuracy: 0.8319 - val_precison: 0.8380 - val_recall: 0.8250
#
# Epoch 00100: val_loss did not improve from 0.44960

# %%
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(24, 10))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training accuracy')
    plt.plot(x, val_acc, 'r', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.xlabel('# of epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('# of epochs')
    plt.ylabel('Loss')
    plt.legend()

plot_history(history)

# %%
from keras.models import load_model

saved_model = tf.keras.models.load_model('./best_model_DISTIL_task2-CLS.h5', custom_objects={"TFDistilBertModel": TFDistilBertModel})

# %%
y_pred = [] 
y_true = [] 

for inputs_id_mask_batch, class_batch in dataset_test:   
   y_true.append(np.argmax(class_batch, axis = -1))
   preds = saved_model.predict(inputs_id_mask_batch)
   y_pred.append(np.argmax(preds, axis = - 1))

correct_labels = tf.concat([item for item in y_true], axis = 0)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)

# %%
cm = confusion_matrix(correct_labels, predicted_labels)

sns.heatmap(cm, annot=True)
plt.title("Confusion Matrix")
plt.ylabel('Correct Values')
plt.xlabel('Predicted Values')
plt.show()
print()
print(classification_report(correct_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.83      0.80       958
#            1       0.91      0.85      0.88      2367
#            2       0.56      0.69      0.62       292
#
#     accuracy                           0.83      3617
#    macro avg       0.74      0.79      0.76      3617
# weighted avg       0.84      0.83      0.84      3617
